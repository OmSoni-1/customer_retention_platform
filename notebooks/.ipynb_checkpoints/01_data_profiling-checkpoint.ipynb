# %%
import pandas as pd
from pathlib import Path

# %%
BASE_DIR = Path.cwd().resolve().parent
DATA_DIR = BASE_DIR / "Data" / "raw"

# %%
all_files = DATA_DIR.glob("*.xlsx")
print(all_files)

# %%
dfs = {file.stem: pd.read_excel(file) for file in all_files}
dfs
# Out:
# {'CustomerChurn':       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
#  0        318537  7590-VHVEG             No     Yes         No       1
#  1        152148  5575-GNVDE             No      No         No      34
#  2        326527  3668-QPYBK             No      No         No       2
#  3        845894  7795-CFOCW             No      No         No      45
#  4        503388  9237-HQITU             No      No         No       2
#  ...         ...         ...            ...     ...        ...     ...
#  7038     810338  6840-RESVB             No     Yes        Yes      24
#  7039     230811  2234-XADUH             No     Yes        Yes      72
#  7040     155157  4801-JZAZL             No     Yes        Yes      11
#  7041     731782  8361-LTMKD            Yes     Yes         No       4
#  7042     353947  3186-AJIEK             No      No         No      66
#
#       Phone Service    Multiple Lines Internet Service Online Security  ...  \
# ...

# %%
tables = {
    "customer_churn": pd.read_excel(Path.cwd().resolve().parent/"data"/"raw"/"CustomerChurn.xlsx"),
    "telco_master": pd.read_excel(Path.cwd().resolve().parent/"data"/"raw"/"Telco_customer_churn.xlsx"),
    "customer_demographics": pd.read_excel(Path.cwd().resolve().parent/"data"/"raw"/"Telco_customer_churn_demographics.xlsx"),
    "customer_location": pd.read_excel(Path.cwd().resolve().parent/"data"/"raw"/"Telco_customer_churn_location.xlsx"),
    "customer_population": pd.read_excel(Path.cwd().resolve().parent/"data"/"raw"/"Telco_customer_churn_population.xlsx"),
    "customer_services": pd.read_excel(Path.cwd().resolve().parent/"data"/"raw"/"Telco_customer_churn_services.xlsx"),
    "customer_status": pd.read_excel(Path.cwd().resolve().parent/"data"/"raw"/"Telco_customer_churn_status.xlsx")
}

# %%
print(tables)
type(tables)
# Out:
# {'customer_churn':       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0        318537  7590-VHVEG             No     Yes         No       1
# 1        152148  5575-GNVDE             No      No         No      34
# 2        326527  3668-QPYBK             No      No         No       2
# 3        845894  7795-CFOCW             No      No         No      45
# 4        503388  9237-HQITU             No      No         No       2
# ...         ...         ...            ...     ...        ...     ...
# 7038     810338  6840-RESVB             No     Yes        Yes      24
# 7039     230811  2234-XADUH             No     Yes        Yes      72
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  ...  \
# ...

# %%
combined_df = pd.DataFrame(tables[1][1])

combined_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 combined_df = pd.DataFrame(tables[1][1])
#       2
#       3 combined_df
#
# KeyError: 1
